# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import math as m

# %%
wine_df = pd.read_csv('winequality-red.csv')

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# **НАНЫ**

# %%
wine_df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# **ПОСТРОИМ ГРАФИКИ ЗАВИСИМОСТИ ТАРГЕТА ОТ ВСЕХ ПРИЗНАКОВ**

# %%
feats = wine_df.loc[:, ~wine_df.columns.isin(['quality'])].columns
fig = make_subplots(rows=m.ceil(len(feats) / 2), cols=2, subplot_titles=feats, vertical_spacing=0.025)
for number, feature in enumerate(feats):
    row=number // 2 + 1
    col=number % 2 + 1
    fig.add_trace(
        go.Scatter(
            x=wine_df[feature], 
            y=wine_df['quality'], 
            mode='markers', 
            name=feature
        ), 
        row=row, 
        col=col, 
    )
    fig.update_xaxes(title_text=feature, row=row, col=col)
    fig.update_yaxes(title_text='quality', row=row, col=col)
fig.update_layout(height=3000)
fig.show()

# %%
corr = wine_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5b700_row0_col0, #T_5b700_row1_col1, #T_5b700_row2_col2, #T_5b700_row3_col3, #T_5b700_row4_col4, #T_5b700_row5_col5, #T_5b700_row6_col6, #T_5b700_row7_col7, #T_5b700_row8_col8, #T_5b700_row9_col9, #T_5b700_row10_col10, #T_5b700_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5b700_row0_col1, #T_5b700_row4_col11, #T_5b700_row9_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_5b700_row0_col2 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_5b700_row0_col3, #T_5b700_row4_col10 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_5b700_row0_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_5b700_row0_col5, #T_5b700_row0_col8, #T_5b700_row1_col2, #T_5b700_row1_col9, #T_5b700_row1_col11, #T_5b700_row2_col1, #T_5b700_row7_col10, #T_5b700_row8_col0, #T_5b700_row8_col3, #T_5b700_row8_col4, #T_5b700_row10_col6, #T_5b700_row10_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# ...

# %%
visual_wine_df = wine_df.copy()
visual_wine_df['quality'] = visual_wine_df['quality'].astype(str)
fig = px.scatter_matrix(visual_wine_df, color="quality", height=4000, width=4000)
fig.show('browser')

# %% [markdown]
# # **ДЗ**
# 1. поиск аномалий (методичка)
# 2. уменьшение размерности
